# %%
# Expressions
# addition
42 + 10 + 50
# Out:
# 102

# %%
# subtraction
50 - 60
# Out:
# -10

# %%
# multiplication
5*5
# Out:
# 25

# %%
# division
25 / 5
# Out:
# 5.0

# %%
# division
25 / 6
# Out:
# 4.166666666666667

# %%
# integer division
25 // 5
# Out:
# 5

# %%
# integer division
25 // 6
# Out:
# 4

# %%
# expression
30 + 2*60
# Out:
# 150

# %%
# expression
160 // 6
# Out:
# 26

# %%
# expression
(30 + 2)*60
# Out:
# 1920

# %%
x = 43 + 60 + 16 + 41
print(x)          # 160
y = x / 60
print(y)          # 2.666...
# keep original x; if you need a minutes version use a new name
x_minutes = y
# Out:
# 160
# 2.6666666666666665

# %%
# rename variable
total_min = 43 + 60 + 16 + 41
print(total_min)
total_hours = total_min / 60
total_hours
# Out:
# 160
# 2.6666666666666665

# %%
# example
sum = 30 + 20 - 40
sum
# Out:
# 10

# %%
# example
res = (55 - 5)/10
res
# Out:
# 5.0

# %%
# example
res = (6*10)/12
res
# Out:
# 5.0

# %%
# example
x = 3 + 2 * 2
x
# Out:
# 7

# %%
# example
y = (3 + 2) * 2
y
# Out:
# 10

# %%
# example
z = x + y
z
# Out:
# 17
