# %%
# system info about float type
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
# values
print(12) #int
print(3.14) #float
print("Hello, World!") #string
# Out:
# 12
# 3.14
# Hello, World!

# %%
# convert int to float and check type
conv = float(2)
print(conv)
print(type(conv))

# convert float to int and lose information
convv = int(1.1)
print(convv)
print(type(convv))
# Out:
# 2.0
# <class 'float'>
# 1
# <class 'int'>

# %%
# convert str to int, error
# int('1 or 2 people')

# convert str '1.2' to float
float('1.2')
# Out:
# 1.2

# %%
# Converting nums to strings
str(1.2)
# Out:
# '1.2'

# %%
# Converting nums to strings
str(1)
# Out:
# '1'

# %%
# boolean
True
# Out:
# True

# %%
# boolean
False
# Out:
# False

# %%
# type bool
type(True)
# Out:
# bool

# %%
# type bool
type(False)
# Out:
# bool

# %%
# convert True to int
int(True)
# Out:
# 1

# %%
# convert False to int
int(False)
# Out:
# 0

# %%
# convert 1 to bool
bool(1)
# Out:
# True

# %%
# convert 0 to bool
bool(0)
# Out:
# False

# %%
# convert True to float
float (True)
# Out:
# 1.0

# %%
# data type of the solution
type(6/2)
# Out:
# float

# %%
# data type of the solution - // int division
type(6//2)
# Out:
# int

# %%
type("Hello, World!")
# Out:
# str

# %%
type("hello" == "world")
# Out:
# bool

# %%
int("1001")
# Out:
# 1001

# %%
float(12434.56)
# Out:
# 12434.56

# %%
str("123-456-7890")
# Out:
# '123-456-7890'
